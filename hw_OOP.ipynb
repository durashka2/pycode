# %%
def mid_grade_counter(list):
    if len(list) == 0:
        return 0
    else:
        grade_sum = 0
        grade_len = 0
        for key, value in list.items():
            grade_sum += sum(value)
            grade_len += len(value)
        return grade_sum / grade_len
student_grades_list = {}
lecturers_grades_list = {}
class Student:
    def __init__(self, name, surname, gender, mid_grade = 0):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.mid_grade = 0
    def rate_lc(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturers_grades_list:
                lecturers_grades_list[course] += [int(grade)]
            else:
                lecturers_grades_list[course] = [int(grade)] 
            if course in lecturer.grades:
                lecturer.grades[course] += [int(grade)]
            else:
                lecturer.grades[course] = [int(grade)]
        else:
            return 'Ошибка'
    def __str__(self):
        mid_grade = mid_grade_counter(self.grades)       
        return f'Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка: {mid_grade}\nКурсы в процессе изучения: {(", ".join(self.courses_in_progress))}\nЗавершенные курсы: {(", ".join(self.finished_courses))}'
    def __eq__(self, other):
        if isinstance(other, Student):
            return (mid_grade_counter(self.grades) == mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def __lt__(self, other):
        if isinstance(other, Student):
            return (mid_grade_counter(self.grades) < mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def __gt__(self, other):
        if isinstance(other, Student):
            return (mid_grade_counter(self.grades) > mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def mid_grade_list(course):
        if course in student_grades_list:
            return sum(student_grades_list[course]) / len(student_grades_list[course])
        else:
            return 'Нет такого курса.'        

class Mentor:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.courses_attached = []

class Lecturer(Mentor):
    def __init__(self, name, surname, gender):
        Mentor.__init__(self, name, surname, gender)
        self.grades = {}
    def __str__(self):
        grade_sum = 0
        grade_len = 0
        for key,value in self.grades.items():
            grade_sum += sum(value)
            grade_len += len(value)
        return f'Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка: {grade_sum / grade_len}'
    def __eq__(self, other):
        if isinstance(other, Lecturer):
            return (mid_grade_counter(self.grades) == mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def __lt__(self, other):
        if isinstance(other, Lecturer):
            return (mid_grade_counter(self.grades) < mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def __gt__(self, other):
        if isinstance(other, Lecturer):
            return (mid_grade_counter(self.grades) > mid_grade_counter(other.grades))
        else:
            return 'Ошибка'
    def mid_grade_list(course):
        if course in lecturers_grades_list:
            return sum(lecturers_grades_list[course]) / len(lecturers_grades_list[course])
        else:
            return 'Нет такого курса.'

class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student_grades_list:
                student_grades_list[course] += [int(grade)]
            else:
                student_grades_list[course] = [int(grade)]
            if course in student.grades:
                student.grades[course] += [int(grade)]            
            else:
                student.grades[course] = [int(grade)]                   
        else:
            return 'Ошибка'
    def __str__(self):
        return f'Имя: {self.name}\nФамилия: {self.surname}'
 
student1 = Student('Dan','Shman','male')
student2 = Student('Mary','Shmary','female')
mentor1 = Mentor('Nick','Shnick','male')
mentor2 = Mentor('Beth','Shbeth','female')
lecturer1 = Lecturer('Ben','Shben','male')
lecturer2 = Lecturer('Sharon','Sharon','female')
reviewer1 = Reviewer('Biley','Shbiley','male')
reviewer2 = Reviewer('Liz','Shliz','female')

student1.courses_in_progress += ['Python','C++']
student2.courses_in_progress += ['Python','C++']
mentor1.courses_attached += ['Python','C++']
mentor1.courses_attached += ['Python','C++']
lecturer1.courses_attached += ['Python','C++']
lecturer2.courses_attached += ['Python','C++']
reviewer1.courses_attached += ['Python','C++']
reviewer2.courses_attached += ['Python','C++']

reviewer1.rate_hw(student1, 'Python','5')
reviewer1.rate_hw(student1, 'C++','7')
reviewer2.rate_hw(student2, 'Python','9')
reviewer2.rate_hw(student2, 'C++','1')

student1.rate_lc(lecturer1, 'Python','1')
student1.rate_lc(lecturer1, 'C++','3')
student2.rate_lc(lecturer2, 'Python','2')
student2.rate_lc(lecturer2, 'C++','8')

print(student1 == student2)
print(student1 > student2)
print(lecturer1 == lecturer2)
print(lecturer1 < lecturer2)

print(Student.mid_grade_list('Python'))
print(Lecturer.mid_grade_list('C++'))

print(student1)
print(lecturer1)
print(reviewer1)
# Out:
# False
# True
# False
# True
# 7.0
# 5.5
# Имя: Dan
# Фамилия: Shman
# Средняя оценка: 6.0
# Курсы в процессе изучения: Python, C++
# Завершенные курсы:
# Имя: Ben
# Фамилия: Shben
# Средняя оценка: 2.0
# Имя: Biley
# Фамилия: Shbiley
